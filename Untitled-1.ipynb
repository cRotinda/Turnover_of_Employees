# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
import os
# %matplotlib inline

# %%
##Importing the csv file into Pandas
df=pd.read_csv("C:\Projects\Employee_Turnover/turnover.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
##Checking for Null Values
df.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# sales                    False
# salary                   False
# dtype: bool

# %%
##Renaming the columns for easier acccess
df = df.rename(columns={
    "satisfaction_level": "satisfaction",
    "last_evaluation": "evaluation",
    "number_project": "projectCount",
    "average_montly_hours": "averageMonthlyHours",
    "time_spend_company": "yearsAtCompany",
    "Work_accident": "workAccident",
    "left": "turnover",
    "promotion_last_5years": "promotion",
    "sales": "department",
    "salary": "pay"
})
df
# Out:
#        satisfaction  evaluation  projectCount  averageMonthlyHours  \
# 0              0.38        0.53             2                  157
# 1              0.80        0.86             5                  262
# 2              0.11        0.88             7                  272
# 3              0.72        0.87             5                  223
# 4              0.37        0.52             2                  159
# ...             ...         ...           ...                  ...
# 14994          0.40        0.57             2                  151
# 14995          0.37        0.48             2                  160
# 14996          0.37        0.53             2                  143
# 14997          0.11        0.96             6                  280
# 14998          0.37        0.52             2                  158
#
#        yearsAtCompany  workAccident  turnover  promotion department     pay
# 0                   3             0         1          0      sales     low
# ...

# %%
##Putting the hasLeft Column first for better understanding
front=df["turnover"]
df.drop(labels="turnover",axis=1,inplace=True)
df.insert(0,"turnover",front)
df.head()
# Out:
#    turnover  satisfaction  evaluation  projectCount  averageMonthlyHours  \
# 0         1          0.38        0.53             2                  157
# 1         1          0.80        0.86             5                  262
# 2         1          0.11        0.88             7                  272
# 3         1          0.72        0.87             5                  223
# 4         1          0.37        0.52             2                  159
#
#    yearsAtCompany  workAccident  promotion department     pay
# 0               3             0          0      sales     low
# 1               6             0          0      sales  medium
# 2               4             0          0      sales  medium
# 3               5             0          0      sales     low
# 4               3             0          0      sales     low

# %%
##The dataset has 14999 rows and 10 columns
df.shape
# Out:
# (14999, 10)

# %%
##Showing the precentage of the employees who stayed and left
turnover_value=df.turnover.value_counts()/len(df)
turnover_value
# Out:
# 0    0.761917
# 1    0.238083
# Name: turnover, dtype: float64

# %%
df.describe()
# Out:
#            turnover  satisfaction    evaluation  projectCount  \
# count  14999.000000  14999.000000  14999.000000  14999.000000
# mean       0.238083      0.612834      0.716102      3.803054
# std        0.425924      0.248631      0.171169      1.232592
# min        0.000000      0.090000      0.360000      2.000000
# 25%        0.000000      0.440000      0.560000      3.000000
# 50%        0.000000      0.640000      0.720000      4.000000
# 75%        0.000000      0.820000      0.870000      5.000000
# max        1.000000      1.000000      1.000000      7.000000
#
#        averageMonthlyHours  yearsAtCompany  workAccident     promotion
# count         14999.000000    14999.000000  14999.000000  14999.000000
# mean            201.050337        3.498233      0.144610      0.021268
# std              49.943099        1.460136      0.351719      0.144281
# min              96.000000        2.000000      0.000000      0.000000
# ...

# %%
turnover_Summary=df.groupby("turnover")
turnover_Summary.mean()
# Out:
# C:\Users\watth\AppData\Local\Temp\ipykernel_16664\1990179255.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   turnover_Summary.mean()
#           satisfaction  evaluation  projectCount  averageMonthlyHours  \
# turnover
# 0             0.666810    0.715473      3.786664           199.060203
# 1             0.440098    0.718113      3.855503           207.419210
#
#           yearsAtCompany  workAccident  promotion
# turnover
# 0               3.380032      0.175009   0.026251
# 1               3.876505      0.047326   0.005321

# %%
empl_satisfaction=df["satisfaction"][df["turnover"]==0].mean()
turnover_satisfaction=df["satisfaction"][df["turnover"]==1].mean()
print("The average satisfaction of a working employee is "+str(empl_satisfaction))
print("The average satisfaction of a leaving employee is "+str(turnover_satisfaction))
# Out:
# The average satisfaction of a working employee is 0.666809590479524
# The average satisfaction of a leaving employee is 0.4400980117614114
